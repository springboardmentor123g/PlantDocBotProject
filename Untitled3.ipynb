# %% [markdown]
# <a href="https://colab.research.google.com/github/springboardmentor123g/PlantDocBotProject/blob/Intern-PavanKumar/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# Get the public URL from previous cell
# Replace with your actual ngrok URL
test_url = str("https://hydrographic-rhetorically-spring.ngrok-free.dev")  # This should automatically use the URL from Cell 12

print("🧪 Testing API endpoints...\n")

# Test health endpoint
print("1️⃣ Testing health check...")
response = requests.get(f"{test_url}/health")
print(f"Status: {response.status_code}")
print(f"Response: {response.json()}\n")

# Test prediction (you need to upload a test image first)
print("2️⃣ To test prediction, upload a plant image and run:")
print(f"""
# Upload image in Colab
from google.colab import files
uploaded = files.upload()

# Get filename
filename = list(uploaded.keys())[0]

# Test prediction
files = {{'file': open(filename, 'rb')}}
response = requests.post(f"{test_url}/predict", files=files)
print(response.json())
""")

# %%
# Upload image in Colab
from google.colab import files
uploaded = files.upload()

# Get filename
filename = list(uploaded.keys())[0]

# Test prediction
files = {'file': open(filename, 'rb')}
response = requests.post(f"https://hydrographic-rhetorically-spring.ngrok-free.dev/predict", files=files)

print(response.json())
